# %% [markdown]
# Import Libraries such as Pandas, Datasets, Matplotlib.pyplot and Seaborn.

# %%
# Importing Libraries
import ast # For string conversion into list object
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick # To add percentage sign to y axis ticks

plt.close('all') # close all open plots

import seaborn as sns

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
# make datetime string into datetime object
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# in column job_skills, make list from string into panda series (list) object using ast.literal_eval
df["job_skills"] = df["job_skills"].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else None)

# %% [markdown]
# # How do the top 5 demanded skills trend over the year?

# %% [markdown]
# I filter the dataframe to show job postings from the United Kingdom whilst ensuring to create a copy of it also for data integrity.

# %%
# Filter df for jobs in United Kingdom
df_UK = df[(df["job_country"] == "United Kingdom")].copy()

# %% [markdown]
# I add new column called job_posted_month which extracts the month number from column job_posted_date. This extracted month is to run on the x axis on the final line plot albeit in month-word format.

# %%
df_UK["job_posted_month_no"] = df_UK["job_posted_date"].dt.month

df_UK
# Out:
#               job_title_short  \
# 15              Data Engineer
# 45        Senior Data Analyst
# 74               Data Analyst
# 97               Data Analyst
# 152            Data Scientist
# ...                       ...
# 785485           Data Analyst
# 785513         Data Scientist
# 785522          Data Engineer
# 785642          Data Engineer
# 785676  Senior Data Scientist
#
#                                                 job_title    job_location  \
# 15                                          Data Engineer    Aberdeen, UK
# 45                                    Senior Data Analyst       Leeds, UK
# 74                       Data Entry/Economic Data Analyst   Worcester, UK
# 97      Systems & Data Analyst - Exploitation, Missing...  United Kingdom
# 152                                Data Science Team Lead        Anywhere
# ...                                                   ...             ...
# 785485                               Data Quality Analyst        Anywhere
# 785513                                     Data Scientist     Glasgow, UK
# 785522                                 Lead Data Engineer      London, UK
# 785642  Submission for the position: Data Engineer Sen...     England, UK
# 785676                              Senior Data Scientist      London, UK
#
#                             job_via         job_schedule_type  \
# 15                     via LinkedIn                 Temp work
# 45            via My Stateline Jobs                 Full-time
# 74                        via BeBee                 Full-time
# 97                    via Totaljobs  Full-time and Contractor
# 152                via OnlyDataJobs                 Full-time
# ...                             ...                       ...
# 785485                 via LinkedIn                 Full-time
# 785513         via Jobs Trabajo.org                 Full-time
# 785522         via Jobs Trabajo.org                 Full-time
# 785642  via BAE Systems - Talentify                 Full-time
# 785676         via Jobs Trabajo.org                 Full-time
#
#         job_work_from_home search_location     job_posted_date  \
# 15                   False  United Kingdom 2023-10-19 13:37:16
# 45                   False  United Kingdom 2023-05-30 13:14:08
# 74                   False  United Kingdom 2023-11-01 13:11:18
# 97                   False  United Kingdom 2023-12-04 13:14:01
# 152                   True  United Kingdom 2023-12-23 13:12:16
# ...                    ...             ...                 ...
# 785485                True  United Kingdom 2023-10-04 06:09:44
# 785513               False  United Kingdom 2023-01-22 06:21:21
# 785522               False  United Kingdom 2023-01-19 06:16:45
# 785642               False  United Kingdom 2023-01-02 06:31:23
# 785676               False  United Kingdom 2023-01-22 06:21:23
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 15                      False                 False  United Kingdom
# 45                       True                 False  United Kingdom
# 74                      False                 False  United Kingdom
# 97                       True                 False  United Kingdom
# 152                     False                 False  United Kingdom
# ...                       ...                   ...             ...
# 785485                  False                 False  United Kingdom
# 785513                  False                 False  United Kingdom
# 785522                   True                 False  United Kingdom
# 785642                   True                 False  United Kingdom
# 785676                  False                 False  United Kingdom
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 15             NaN              NaN              NaN
# 45             NaN              NaN              NaN
# 74             NaN              NaN              NaN
# 97             NaN              NaN              NaN
# 152            NaN              NaN              NaN
# ...            ...              ...              ...
# 785485         NaN              NaN              NaN
# 785513         NaN              NaN              NaN
# 785522         NaN              NaN              NaN
# 785642         NaN              NaN              NaN
# 785676         NaN              NaN              NaN
#
#                                     company_name  \
# 15                                   Orion Group
# 45                            Corecom Consulting
# 74                            ttgTalentSolutions
# 97         Solihull Metropolitan Borough Council
# 152                              StepStone Group
# ...                                          ...
# 785485                                   Viatris
# 785513                           ASA Recruitment
# 785522                       bionic-services-ltd
# 785642                          BAE Systems - UK
# 785676  Department for International Development
#
#                                                job_skills  \
# 15                                [python, sql, power bi]
# 45                                          [sql, python]
# 74                    [sql, r, python, tableau, power bi]
# 97                                                   None
# 152                                       [react, docker]
# ...                                                   ...
# 785485               [sql, sql server, excel, powerpoint]
# 785513                                      [r, power bi]
# 785522    [sql, python, sql server, aws, snowflake, ssis]
# 785642  [python, vue, ssis, ssrs, qlik, confluence, jira]
# 785676                                        [r, python]
#
#                                           job_type_skills  job_posted_month_no
# 15      {'analyst_tools': ['power bi'], 'programming':...                   10
# 45                     {'programming': ['sql', 'python']}                    5
# 74      {'analyst_tools': ['tableau', 'power bi'], 'pr...                   11
# 97                                                    NaN                   12
# 152         {'libraries': ['react'], 'other': ['docker']}                   12
# ...                                                   ...                  ...
# 785485  {'analyst_tools': ['excel', 'powerpoint'], 'da...                   10
# 785513  {'analyst_tools': ['power bi'], 'programming':...                    1
# 785522  {'analyst_tools': ['ssis'], 'cloud': ['aws', '...                    1
# 785642  {'analyst_tools': ['ssis', 'ssrs', 'qlik'], 'a...                    1
# 785676                   {'programming': ['r', 'python']}                    1
#
# [40375 rows x 18 columns]

# %% [markdown]
# As I have made the values in column job_skills from string into list object, they are now 'explodable' and can be exploded into multiple rows. Below they are exploded.

# %%
df_UK_exploded = df_UK.explode("job_skills")

df_UK_exploded
# Out:
#               job_title_short  \
# 15              Data Engineer
# 15              Data Engineer
# 15              Data Engineer
# 45        Senior Data Analyst
# 45        Senior Data Analyst
# ...                       ...
# 785642          Data Engineer
# 785642          Data Engineer
# 785642          Data Engineer
# 785676  Senior Data Scientist
# 785676  Senior Data Scientist
#
#                                                 job_title  job_location  \
# 15                                          Data Engineer  Aberdeen, UK
# 15                                          Data Engineer  Aberdeen, UK
# 15                                          Data Engineer  Aberdeen, UK
# 45                                    Senior Data Analyst     Leeds, UK
# 45                                    Senior Data Analyst     Leeds, UK
# ...                                                   ...           ...
# 785642  Submission for the position: Data Engineer Sen...   England, UK
# 785642  Submission for the position: Data Engineer Sen...   England, UK
# 785642  Submission for the position: Data Engineer Sen...   England, UK
# 785676                              Senior Data Scientist    London, UK
# 785676                              Senior Data Scientist    London, UK
#
#                             job_via job_schedule_type  job_work_from_home  \
# 15                     via LinkedIn         Temp work               False
# 15                     via LinkedIn         Temp work               False
# 15                     via LinkedIn         Temp work               False
# 45            via My Stateline Jobs         Full-time               False
# 45            via My Stateline Jobs         Full-time               False
# ...                             ...               ...                 ...
# 785642  via BAE Systems - Talentify         Full-time               False
# 785642  via BAE Systems - Talentify         Full-time               False
# 785642  via BAE Systems - Talentify         Full-time               False
# 785676         via Jobs Trabajo.org         Full-time               False
# 785676         via Jobs Trabajo.org         Full-time               False
#
#        search_location     job_posted_date  job_no_degree_mention  \
# 15      United Kingdom 2023-10-19 13:37:16                  False
# 15      United Kingdom 2023-10-19 13:37:16                  False
# 15      United Kingdom 2023-10-19 13:37:16                  False
# 45      United Kingdom 2023-05-30 13:14:08                   True
# 45      United Kingdom 2023-05-30 13:14:08                   True
# ...                ...                 ...                    ...
# 785642  United Kingdom 2023-01-02 06:31:23                   True
# 785642  United Kingdom 2023-01-02 06:31:23                   True
# 785642  United Kingdom 2023-01-02 06:31:23                   True
# 785676  United Kingdom 2023-01-22 06:21:23                  False
# 785676  United Kingdom 2023-01-22 06:21:23                  False
#
#         job_health_insurance     job_country salary_rate  salary_year_avg  \
# 15                     False  United Kingdom         NaN              NaN
# 15                     False  United Kingdom         NaN              NaN
# 15                     False  United Kingdom         NaN              NaN
# 45                     False  United Kingdom         NaN              NaN
# 45                     False  United Kingdom         NaN              NaN
# ...                      ...             ...         ...              ...
# 785642                 False  United Kingdom         NaN              NaN
# 785642                 False  United Kingdom         NaN              NaN
# 785642                 False  United Kingdom         NaN              NaN
# 785676                 False  United Kingdom         NaN              NaN
# 785676                 False  United Kingdom         NaN              NaN
#
#         salary_hour_avg                              company_name  job_skills  \
# 15                  NaN                               Orion Group      python
# 15                  NaN                               Orion Group         sql
# 15                  NaN                               Orion Group    power bi
# 45                  NaN                        Corecom Consulting         sql
# 45                  NaN                        Corecom Consulting      python
# ...                 ...                                       ...         ...
# 785642              NaN                          BAE Systems - UK        qlik
# 785642              NaN                          BAE Systems - UK  confluence
# 785642              NaN                          BAE Systems - UK        jira
# 785676              NaN  Department for International Development           r
# 785676              NaN  Department for International Development      python
#
#                                           job_type_skills  job_posted_month_no
# 15      {'analyst_tools': ['power bi'], 'programming':...                   10
# 15      {'analyst_tools': ['power bi'], 'programming':...                   10
# 15      {'analyst_tools': ['power bi'], 'programming':...                   10
# 45                     {'programming': ['sql', 'python']}                    5
# 45                     {'programming': ['sql', 'python']}                    5
# ...                                                   ...                  ...
# 785642  {'analyst_tools': ['ssis', 'ssrs', 'qlik'], 'a...                    1
# 785642  {'analyst_tools': ['ssis', 'ssrs', 'qlik'], 'a...                    1
# 785642  {'analyst_tools': ['ssis', 'ssrs', 'qlik'], 'a...                    1
# 785676                   {'programming': ['r', 'python']}                    1
# 785676                   {'programming': ['r', 'python']}                    1
#
# [167546 rows x 18 columns]

# %% [markdown]
# I aggregate the number of each skill posted in each month in a pivot table. I ensure to use fill_value=0 to fill empty cells with 0. I assign this pivot table to the variable df_UK_exploded_pivot.

# %%
df_UK_exploded_pivot = df_UK_exploded.pivot_table(
    index="job_posted_month_no",
    columns="job_skills",
    aggfunc="size",
    fill_value=0, # fill empty cells with 0 instead of NaN
    
)

df_UK_exploded_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  ansible  arch  \
# job_posted_month_no
# 1                        209         2       73        8       21     2
# 2                        149         1       48        6       24     1
# 3                         98         0       42        5       17     0
# 4                         98         0       27        4       22     0
# 5                        115         4       23        1       20     0
# 6                        158         0       25        3       18     0
# 7                        181         0       33        1       34     0
# 8                        129         0       29        0       20     0
# 9                        160         2       69        2       43     2
# 10                       220         2       69        7       25     2
# 11                       189         1       39       12       19     1
# 12                       165         0       58        4       13     1
#
# job_skills           asana  asp.net  asp.net core  assembly  ...  watson  \
# job_posted_month_no                                          ...
# 1                        2        4             1         5  ...       1
# 2                        0        1             0         7  ...      12
# 3                        0        1             0         1  ...       7
# 4                        0        1             0         1  ...       2
# 5                        2        0             0         2  ...       4
# 6                        0        1             0         2  ...       0
# 7                        1        3             0         5  ...       1
# 8                        3        1             0         2  ...       0
# 9                        8        4             0         1  ...       3
# 10                       0        3             0        11  ...       4
# 11                       1        3             1         6  ...       2
# 12                       1        1             0         3  ...       1
#
# job_skills           webex  windows  wire  word  workfront  wrike  wsl  yarn  \
# job_posted_month_no
# 1                        0       37     0   105          0      0    1     5
# 2                        0       36     0    99          1      0    0     6
# 3                        0       21     0    71          0      0    0     3
# 4                        0       18     0    45          0      0    0     2
# 5                        0       11     0    51          0      0    0     4
# 6                        0        4     0    61          0      0    0     6
# 7                        0       24     1    73          0      0    0     4
# 8                        0       15     4    61          0      0    0     5
# 9                        0       39     0    95          0      1    0     4
# 10                       0       48     1   135          0      0    1     0
# 11                       0       42     3    85          0      0    1     1
# 12                       2       36     2    81          0      0    0     2
#
# job_skills           zoom
# job_posted_month_no
# 1                       8
# 2                       5
# 3                       3
# 4                       1
# 5                       8
# 6                       3
# 7                       7
# 8                       6
# 9                       3
# 10                      7
# 11                      0
# 12                      6
#
# [12 rows x 215 columns]

# %% [markdown]
# PROBLEM: I want the columns to be in descending order according to the skills which have the highest count (aggregated by size in the pivot table). The columns are currently in alphabetical order.
# SOLUTION:  Add a Total row at the bottom of the pivot table. This aggregates the counts of each skill and displays it at the bottom of the pivot table. Then, sort columns in descending order based on the values of this Total row.
# Note: I didn't use margins on the pivot table as although they may seem simpler, but, it was returning some errors in the Pandas mechanism. So, I used this workaround instead.

# %% [markdown]
# Add Total row

# %%
df_UK_exploded_pivot.loc["Total"] = df_UK_exploded_pivot.sum()

df_UK_exploded_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  ansible  arch  \
# job_posted_month_no
# 1                        209         2       73        8       21     2
# 2                        149         1       48        6       24     1
# 3                         98         0       42        5       17     0
# 4                         98         0       27        4       22     0
# 5                        115         4       23        1       20     0
# 6                        158         0       25        3       18     0
# 7                        181         0       33        1       34     0
# 8                        129         0       29        0       20     0
# 9                        160         2       69        2       43     2
# 10                       220         2       69        7       25     2
# 11                       189         1       39       12       19     1
# 12                       165         0       58        4       13     1
# Total                   1871        12      535       53      276     9
#
# job_skills           asana  asp.net  asp.net core  assembly  ...  watson  \
# job_posted_month_no                                          ...
# 1                        2        4             1         5  ...       1
# 2                        0        1             0         7  ...      12
# 3                        0        1             0         1  ...       7
# 4                        0        1             0         1  ...       2
# 5                        2        0             0         2  ...       4
# 6                        0        1             0         2  ...       0
# 7                        1        3             0         5  ...       1
# 8                        3        1             0         2  ...       0
# 9                        8        4             0         1  ...       3
# 10                       0        3             0        11  ...       4
# 11                       1        3             1         6  ...       2
# 12                       1        1             0         3  ...       1
# Total                   18       23             2        46  ...      37
#
# job_skills           webex  windows  wire  word  workfront  wrike  wsl  yarn  \
# job_posted_month_no
# 1                        0       37     0   105          0      0    1     5
# 2                        0       36     0    99          1      0    0     6
# 3                        0       21     0    71          0      0    0     3
# 4                        0       18     0    45          0      0    0     2
# 5                        0       11     0    51          0      0    0     4
# 6                        0        4     0    61          0      0    0     6
# 7                        0       24     1    73          0      0    0     4
# 8                        0       15     4    61          0      0    0     5
# 9                        0       39     0    95          0      1    0     4
# 10                       0       48     1   135          0      0    1     0
# 11                       0       42     3    85          0      0    1     1
# 12                       2       36     2    81          0      0    0     2
# Total                    2      331    11   962          1      1    3    42
#
# job_skills           zoom
# job_posted_month_no
# 1                       8
# 2                       5
# 3                       3
# 4                       1
# 5                       8
# 6                       3
# 7                       7
# 8                       6
# 9                       3
# 10                      7
# 11                      0
# 12                      6
# Total                  57
#
# [13 rows x 215 columns]

# %% [markdown]
# I sort pivot table columns based on Total row in descending order and then Irop the total row as it is not required any more

# %%
df_UK_exploded_pivot = df_UK_exploded_pivot[df_UK_exploded_pivot.loc["Total"].sort_values(ascending=False).index]

# Drop the total row as it is not required any more
df_UK_exploded_pivot = df_UK_exploded_pivot.drop("Total")

# %% [markdown]
# I then convert the index numbers (index name is job_posted_month_no) to three-letter month names directly using pandas .to_datetime method.

# %%
df_UK_exploded_pivot.index = pd.to_datetime(df_UK_exploded_pivot.index, format='%m').strftime('%b')

# %%
df_UK_exploded_pivot
# Out:
# job_skills            sql  python  azure  aws  excel  power bi    r  tableau  \
# job_posted_month_no
# Jan                  2450    2277    972  840    812       709  675      515
# Feb                  1853    1700    808  712    636       555  478      405
# Mar                  1393    1413    623  569    458       434  406      330
# Apr                   995    1031    435  425    309       293  287      218
# May                  1141    1127    473  471    342       336  318      241
# Jun                  1417    1455    612  595    418       418  354      286
# Jul                  1740    1663    823  708    559       595  418      329
# Aug                  1419    1470    621  560    401       402  382      268
# Sep                  2040    1937    845  791    715       658  548      480
# Oct                  2271    2192    990  908    768       680  598      545
# Nov                  1956    2045    944  807    544       593  510      410
# Dec                  1554    1684    743  666    501       486  436      373
#
# job_skills           spark  gcp  ...  asp.net core  nuix  webex  huggingface  \
# job_posted_month_no              ...
# Jan                    497  414  ...             1     0      0            0
# Feb                    380  326  ...             0     0      0            0
# Mar                    307  243  ...             0     0      0            0
# Apr                    233  191  ...             0     0      0            0
# May                    220  208  ...             0     0      0            0
# Jun                    335  239  ...             0     0      0            0
# Jul                    366  305  ...             0     0      0            0
# Aug                    297  254  ...             0     0      0            0
# Sep                    392  292  ...             0     2      0            1
# Oct                    416  351  ...             0     0      0            0
# Nov                    399  278  ...             1     0      0            0
# Dec                    322  288  ...             0     0      2            0
#
# job_skills           heroku  erlang  ionic  pascal  workfront  wrike
# job_posted_month_no
# Jan                       0       0      0       0          0      0
# Feb                       1       0      0       0          1      0
# Mar                       0       0      0       0          0      0
# Apr                       0       0      1       0          0      0
# May                       0       0      0       0          0      0
# Jun                       0       0      0       1          0      0
# Jul                       0       0      0       0          0      0
# Aug                       0       0      0       0          0      0
# Sep                       0       1      0       0          0      1
# Oct                       0       0      0       0          0      0
# Nov                       0       0      0       0          0      0
# Dec                       0       0      0       0          0      0
#
# [12 rows x 215 columns]

# %% [markdown]
# I create a subset of the data extracting the first 5 columns (top 5 skills) as they have the highest counts. Extraction is done using the .iloc method.

# %%
data_subset = df_UK_exploded_pivot.iloc[:, :5]

data_subset
# Out:
# job_skills            sql  python  azure  aws  excel
# job_posted_month_no
# Jan                  2450    2277    972  840    812
# Feb                  1853    1700    808  712    636
# Mar                  1393    1413    623  569    458
# Apr                   995    1031    435  425    309
# May                  1141    1127    473  471    342
# Jun                  1417    1455    612  595    418
# Jul                  1740    1663    823  708    559
# Aug                  1419    1470    621  560    401
# Sep                  2040    1937    845  791    715
# Oct                  2271    2192    990  908    768
# Nov                  1956    2045    944  807    544
# Dec                  1554    1684    743  666    501

# %% [markdown]
# The subset of data is plotted on a line graph using Pandas (Matplotlib).

# %%
# Plot top 5 skills on line graph using Matplotlib
data_subset.plot(
    kind="line"
)
plt.title("What are the Top 5 Skills for Data Professionals throughout the Year?")
plt.legend(title="Skills")

plt.xlabel("Month")
plt.ylabel("Number of Jobs");

# %% [markdown]
# The subset of data is plotted on a line graph using Seaborn

# %%
# Plot top 5 skills on line graph using Seaborn

sns.set_theme(style="ticks")

sns.lineplot(
    data=data_subset,
    dashes=False,
)

plt.title("What are the Top 5 Skills for Data Professionals throughout the Year?")
plt.legend(title="Skills", bbox_to_anchor=(1.05, 1), loc='upper left') # Make legend sit outside plot on top right by anchoring top left of legend box

plt.xlabel("Month")
plt.ylabel("Number of Jobs");

# %% [markdown]
# # How do the top 5 skills trend throughout the year percentage wise?

# %% [markdown]
# Now, I want to see what percentage of jobs mention the top 5 skills for data professionals. My approach here is to return a aggregate the total number of jobs posted each month using .groupby(). Then, within the exploded pivot table above (df_UK_exploded_pivot), divide every value horizontally by the total number of jobs and then multiply by 100. This returns the percentage.

# %% [markdown]
# I return number of jobs posed each month in a series and assign to variable df_UK_total_jobs.

# %%
df_UK_total_jobs = df_UK.groupby("job_posted_month_no").size()

df_UK_total_jobs
# Out:
# job_posted_month_no
# 1     4781
# 2     3619
# 3     2773
# 4     2094
# 5     2236
# 6     2805
# 7     3187
# 8     2711
# 9     4191
# 10    4664
# 11    3969
# 12    3345
# dtype: int64

# %% [markdown]
# Make the index of df_UK_total_jobs match the index format of df_UK_exploded_pivot. This format is month names. This is essential as Pandas looks at row labels (index) when performing divide operation.

# %%
df_UK_total_jobs.index = pd.to_datetime(df_UK_total_jobs.index, format='%m').strftime('%b')

# %% [markdown]
# Make a percentage pivot dividing the values in df_UK_exploded_pivot by total job counts and then multiplying by 100. Resultant dataframe assigned to variable df_UK_percent.

# %%
df_UK_percent = df_UK_exploded_pivot.div(df_UK_total_jobs, axis=0) * 100

df_UK_percent
# Out:
# job_skills                 sql     python      azure        aws      excel  \
# job_posted_month_no
# Jan                  51.244510  47.626020  20.330475  17.569546  16.983895
# Feb                  51.201989  46.974302  22.326610  19.673943  17.573915
# Mar                  50.234403  50.955644  22.466643  20.519293  16.516408
# Apr                  47.516714  49.235912  20.773639  20.296084  14.756447
# May                  51.028623  50.402504  21.153846  21.064401  15.295170
# Jun                  50.516934  51.871658  21.818182  21.212121  14.901961
# Jul                  54.596799  52.180734  25.823659  22.215249  17.540006
# Aug                  52.342309  54.223534  22.906677  20.656584  14.791590
# Sep                  48.675734  46.218086  20.162252  18.873777  17.060367
# Oct                  48.692110  46.998285  21.226415  19.468268  16.466552
# Nov                  49.281935  51.524313  23.784329  20.332577  13.706223
# Dec                  46.457399  50.343797  22.212257  19.910314  14.977578
#
# job_skills            power bi          r    tableau      spark       gcp  \
# job_posted_month_no
# Jan                  14.829534  14.118385  10.771805  10.395315  8.659276
# Feb                  15.335728  13.208069  11.190937  10.500138  9.008013
# Mar                  15.650920  14.641183  11.900469  11.071042  8.763072
# Apr                  13.992359  13.705826  10.410697  11.127030  9.121299
# May                  15.026834  14.221825  10.778175   9.838998  9.302326
# Jun                  14.901961  12.620321  10.196078  11.942959  8.520499
# Jul                  18.669595  13.115783  10.323188  11.484154  9.570129
# Aug                  14.828477  14.090741   9.885651  10.955367  9.369236
# Sep                  15.700310  13.075638  11.453114   9.353376  6.967311
# Oct                  14.579760  12.821612  11.685249   8.919383  7.525729
# Nov                  14.940791  12.849584  10.330058  10.052910  7.004283
# Dec                  14.529148  13.034380  11.150972   9.626308  8.609865
#
# job_skills           ...  asp.net core      nuix     webex  huggingface  \
# job_posted_month_no  ...
# Jan                  ...      0.020916  0.000000  0.000000     0.000000
# Feb                  ...      0.000000  0.000000  0.000000     0.000000
# Mar                  ...      0.000000  0.000000  0.000000     0.000000
# Apr                  ...      0.000000  0.000000  0.000000     0.000000
# May                  ...      0.000000  0.000000  0.000000     0.000000
# Jun                  ...      0.000000  0.000000  0.000000     0.000000
# Jul                  ...      0.000000  0.000000  0.000000     0.000000
# Aug                  ...      0.000000  0.000000  0.000000     0.000000
# Sep                  ...      0.000000  0.047721  0.000000     0.023861
# Oct                  ...      0.000000  0.000000  0.000000     0.000000
# Nov                  ...      0.025195  0.000000  0.000000     0.000000
# Dec                  ...      0.000000  0.000000  0.059791     0.000000
#
# job_skills             heroku    erlang     ionic    pascal  workfront  \
# job_posted_month_no
# Jan                  0.000000  0.000000  0.000000  0.000000   0.000000
# Feb                  0.027632  0.000000  0.000000  0.000000   0.027632
# Mar                  0.000000  0.000000  0.000000  0.000000   0.000000
# Apr                  0.000000  0.000000  0.047755  0.000000   0.000000
# May                  0.000000  0.000000  0.000000  0.000000   0.000000
# Jun                  0.000000  0.000000  0.000000  0.035651   0.000000
# Jul                  0.000000  0.000000  0.000000  0.000000   0.000000
# Aug                  0.000000  0.000000  0.000000  0.000000   0.000000
# Sep                  0.000000  0.023861  0.000000  0.000000   0.000000
# Oct                  0.000000  0.000000  0.000000  0.000000   0.000000
# Nov                  0.000000  0.000000  0.000000  0.000000   0.000000
# Dec                  0.000000  0.000000  0.000000  0.000000   0.000000
#
# job_skills              wrike
# job_posted_month_no
# Jan                  0.000000
# Feb                  0.000000
# Mar                  0.000000
# Apr                  0.000000
# May                  0.000000
# Jun                  0.000000
# Jul                  0.000000
# Aug                  0.000000
# Sep                  0.023861
# Oct                  0.000000
# Nov                  0.000000
# Dec                  0.000000
#
# [12 rows x 215 columns]

# %% [markdown]
# Extract subset of data which is top 5 skills. Extraction is done using .iloc() method.

# %%
data_percentage_subset = df_UK_percent.iloc[:, :5]

data_percentage_subset
# Out:
# job_skills                 sql     python      azure        aws      excel
# job_posted_month_no
# Jan                  51.244510  47.626020  20.330475  17.569546  16.983895
# Feb                  51.201989  46.974302  22.326610  19.673943  17.573915
# Mar                  50.234403  50.955644  22.466643  20.519293  16.516408
# Apr                  47.516714  49.235912  20.773639  20.296084  14.756447
# May                  51.028623  50.402504  21.153846  21.064401  15.295170
# Jun                  50.516934  51.871658  21.818182  21.212121  14.901961
# Jul                  54.596799  52.180734  25.823659  22.215249  17.540006
# Aug                  52.342309  54.223534  22.906677  20.656584  14.791590
# Sep                  48.675734  46.218086  20.162252  18.873777  17.060367
# Oct                  48.692110  46.998285  21.226415  19.468268  16.466552
# Nov                  49.281935  51.524313  23.784329  20.332577  13.706223
# Dec                  46.457399  50.343797  22.212257  19.910314  14.977578

# %% [markdown]
# Plot subset of data on line graph using Pandas (Matplotlib)

# %%
data_percentage_subset.plot(
    kind="line"
)
plt.title("What are the Top 5 Skills for Data Professionals throughout the Year?")
plt.legend(title="Skills") # Gives a proper legend
plt.xlabel("Month")
# plt.ylabel("Percentage of Jobs") commented out as y axis is self-explanatory

plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0)); # Add percentage sign to y axis ticks

# %% [markdown]
# Plot subset of data on line graph using Seaborn

# %%
sns.lineplot(
    data=data_percentage_subset,
    dashes=False,
)

plt.title("What are the Top 5 Skills for Data Professionals throughout the Year?")
plt.legend(title="Skills"); # Add title to legend
plt.xlabel("Month")
plt.legend(title="Skills", bbox_to_anchor=(1.05, 1), loc='upper left') # Make legend sit outside plot on top right by anchoring top left of legend box

# plt.ylabel("Percentage of Jobs") commented out as y axis is self-explanatory
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(decimals=0)) # Add percentage sign to y axis ticks
